# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = r"D:\Yadh Documents\College Stuff\Pictures\Baby.jpg"

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

image = cv2.imread(image)

grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(grey, scaleFactor=1.1, minNeighbors=6)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 5)

plt.figure(figsize=(4, 3))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
image = r"D:\Yadh Documents\College Stuff\Pictures\Baby.jpg" 
image = cv2.imread(image)
plt.figure(figsize=(4, 3))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
image = r"D:\Yadh Documents\College Stuff\Pictures\Baby.jpg" 
image = cv2.imread(image)


grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

faces = face_cascade.detectMultiScale(grey, scaleFactor = 1.1, minNeighbors = 7)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 5)

plt.figure(figsize=(4, 3))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
image = r"D:\Yadh Documents\College Stuff\Pictures\Baby.jpg" 
image = cv2.imread(image)

grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

faces = face_cascade.detectMultiScale(grey, scaleFactor = 1.1, minNeighbors = 7)

for (x,y,w,h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 5)


plt.figure(figsize = (3,4))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
image = r"D:\Yadh Documents\College Stuff\Pictures\Baby.jpg" 
image = cv2.imread(image)

grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

faces = face_cascade.detectMultiScale(grey, scaleFactor = 1.1, minNeighbors = 7)

for (z,y,w,h) in faces:
    cv2.rectangle(image, (x,y),((x+w), (y+h)), (0,255,0), 7)

plt.figure(figsize = (3,4))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
